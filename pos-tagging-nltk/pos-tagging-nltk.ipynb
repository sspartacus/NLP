# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from nltk.tokenize import word_tokenize 
import nltk 

s = input()

# words = word_tokenize(string)

# nltk.pos_tag(words)

sent = s.split('/')
org_str = []

for i in sent: 
    words = i.split()
    if len(words) <  2: 
        org_str.append(words[0])
    elif len(words) ==  2:
        tag = nltk.pos_tag(words[1])
        tag_two = []
        tag_three = []
        
        for k,v in tag: 
            if len(v) == 2: 
                tag_two.append(v)
            elif len(v) == 3:
                tag_three.append(v)
                
        if words[0] == '??': 
            words[0].replace(words[0], tag_two[0])
        elif words[0] == '???': 
            words[0].replace(words[0], tag_three[0])
        
        org_str.append(' '.join(words))
            
# for item in org_str: 
print ('/'.join(org_str))

# %%
from nltk.tokenize import word_tokenize 
import nltk 

s = input()

sent = s.split()
org_str = []

sent
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#  The/DT planet/NN Jupiter/NNP and/CC its/PPS moons/NNS are/VBP in/IN effect/NN a/DT minisolar/JJ system/?? ,/, and/CC Jupiter/NNP itself/PRP is/VBZ often/RB called/VBN a/DT star/?? that/IN never/RB caught/??? fire/NN ./.
# ['The/DT',
#  'planet/NN',
#  'Jupiter/NNP',
#  'and/CC',
#  'its/PPS',
#  'moons/NNS',
#  'are/VBP',
#  'in/IN',
#  'effect/NN',
#  'a/DT',
#  'minisolar/JJ',
#  'system/??',
#  ',/,',
#  'and/CC',
#  'Jupiter/NNP',
#  'itself/PRP',
#  'is/VBZ',
#  'often/RB',
#  'called/VBN',
#  'a/DT',
#  'star/??',
#  'that/IN',
#  'never/RB',
#  'caught/???',
#  'fire/NN',
#  './.']

# %%
tag_arr = []
words_arr = []

for i in sent: 
    words = i.split('/')
#     words = word_tokenize(i)
    words_arr.append(words)
#     if len(words) <  2: 
#         org_str.append(words[0])
#     if len(words) ==  2:
#         tag = nltk.pos_tag(words[1])
#         tag_arr.append(tag)
        
# tag_arr
words_arr
        
    
#     tag = nltk.pos_tag(words[1])
# Out:
# [['The', 'DT'],
#  ['planet', 'NN'],
#  ['Jupiter', 'NNP'],
#  ['and', 'CC'],
#  ['its', 'PPS'],
#  ['moons', 'NNS'],
#  ['are', 'VBP'],
#  ['in', 'IN'],
#  ['effect', 'NN'],
#  ['a', 'DT'],
#  ['minisolar', 'JJ'],
#  ['system', '??'],
#  [',', ','],
#  ['and', 'CC'],
#  ['Jupiter', 'NNP'],
#  ['itself', 'PRP'],
#  ['is', 'VBZ'],
#  ['often', 'RB'],
#  ['called', 'VBN'],
#  ['a', 'DT'],
#  ['star', '??'],
#  ['that', 'IN'],
#  ['never', 'RB'],
#  ['caught', '???'],
#  ['fire', 'NN'],
#  ['.', '.']]

# %%
tag_arr = []
words_arr = []
org_str = []

for i in sent: 
    words = i.split('/')

    if len(words) <  2: 
        org_str.append(words[0])
    elif len(words) ==  2:
        tag = nltk.pos_tag(words[1])
        tag_arr.append(tag)

        
#         tag_two = []
#         tag_three = []
        
#         for k,v in tag: 
#             if len(v) == 2: 
#                 tag_two.append(v)
#             elif len(v) == 3:
#                 tag_three.append(v)
                
        if words[0] == '??': 
            arr = nltk.pos_tag(words[1])
            
            for item in  arr: 
                if len(item) == 2: 
                    words[0] = words[0].replace(words[0], item[0])
            
        elif words[0] == '???': 
            brr = nltk.pos_tag(words[1])
            
            for item in  brr: 
                if len(item) == 3: 
                    words[0] = words[0].replace(words[0], item[0])
                    
        org_str.append(' '.join(words))
        
org_str

        
        
        
        
# # tag_arr
# words_arr
        
    
#     tag = nltk.pos_tag(words[1])
# Out:
# ['The DT',
#  'planet NN',
#  'Jupiter NNP',
#  'and CC',
#  'its PPS',
#  'moons NNS',
#  'are VBP',
#  'in IN',
#  'effect NN',
#  'a DT',
#  'minisolar JJ',
#  'system ??',
#  ', ,',
#  'and CC',
#  'Jupiter NNP',
#  'itself PRP',
#  'is VBZ',
#  'often RB',
#  'called VBN',
#  'a DT',
#  'star ??',
#  'that IN',
#  'never RB',
#  'caught ???',
#  'fire NN',
#  '. .']

# %%
tag_arr = []
words_arr = []
org_str = []

for i in sent: 
    words = i.split('/')

#     if len(words) <  2: 
#         org_str.append(words[0])
#     elif len(words) ==  2:
    tag = nltk.pos_tag(words[1])
    
    if words[1] == '??': 
        words_in_excerpt = word_tokenize(words[0])
        tag_arr.append(nltk.pos_tag(words_in_excerpt))
        
     
    
tag_arr
            
#             for item in  arr: 
#                 if len(item) == 2: 
#                     words[0] = words[0].replace(words[0], item[0])
# Out:
# [[('system', 'NN')], [('star', 'NN')]]

# %%
tag_arr = []
words_arr = []
org_str = []

for i in sent: 
    words = i.split('/')

    if len(words) <  2: 
        org_str.append(words[0])
    elif len(words) ==  2:
        tag = nltk.pos_tag(words[1])
        
        if words[1] != '??'and words[1] != '???': 
            org_str.append('/'.join(words))

        
        elif words[1] == '??': 
            words_in_excerpt = word_tokenize(words[0])
            arr = nltk.pos_tag(words_in_excerpt)
            
            for item in  arr: 
#                 if len(item[1]) == 2  : 
                words[1] = words[1].replace(words[1], item[1])
                org_str.append('/'.join(words))
    
        
                    
                                
        elif words[1] == '???': 
            words_in_excerpt = word_tokenize(words[0])
            arr = nltk.pos_tag(words_in_excerpt)
            
            for item in  arr: 
#                 if len(item[1]) == 3 or len(item[1]) == 1 or len(item[1]) == 2 :  
                words[1] = words[1].replace(words[1], item[1])
                org_str.append('/'.join(words))
                    
                    
        
        
print (' '.join(org_str))
                    
                    
# org_str
# Out:
# The/DT planet/NN Jupiter/NNP and/CC its/PPS moons/NNS are/VBP in/IN effect/NN a/DT minisolar/JJ system/NN ,/, and/CC Jupiter/NNP itself/PRP is/VBZ often/RB called/VBN a/DT star/NN that/IN never/RB caught/NN fire/NN ./.
